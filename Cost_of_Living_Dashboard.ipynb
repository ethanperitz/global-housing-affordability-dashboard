# %%
import pandas as pd
import numpy as np

# %%
path = "/content/sample_data/cost-of-living_v2.csv"
df = pd.read_csv(path)

# %%
#data dictionary
col_names = {
"x1": "Meal, Inexpensive Restaurant (USD)",
"x2": "Meal for 2 People, Mid-range Restaurant, Three-course (USD)",
"x3": "McMeal at McDonalds (USD)",
"x4": "Domestic Beer (0.5L draught, restaurant) (USD)",
"x5": "Imported Beer (0.33L bottle, restaurant) (USD)",
"x6": "Cappuccino (USD)",
"x7": "Coke/Pepsi (0.33L bottle) (USD)",
"x8": "Water (0.33L bottle, restaurant) (USD)",
"x9": "Milk (1L) (USD)",
"x10": "Loaf of Fresh White Bread (500g) (USD)",
"x11": "Rice (1kg) (USD)",
"x12": "Eggs (12) (USD)",
"x13": "Local Cheese (1kg) (USD)",
"x14": "Chicken Fillets (1kg) (USD)",
"x15": "Beef Round (1kg) (USD)",
"x16": "Apples (1kg) (USD)",
"x17": "Bananas (1kg) (USD)",
"x18": "Oranges (1kg) (USD)",
"x19": "Tomatoes (1kg) (USD)",
"x20": "Potatoes (1kg) (USD)",
"x21": "Onions (1kg) (USD)",
"x22": "Lettuce (1 head) (USD)",
"x23": "Water (1.5L bottle, market) (USD)",
"x24": "Bottle of Wine (Mid-range) (USD)",
"x25": "Domestic Beer (0.5L bottle, market) (USD)",
"x26": "Imported Beer (0.33L bottle, market) (USD)",
"x27": "Cigarettes (20 pack Marlboro) (USD)",
"x28": "One-way Ticket (Local Transport) (USD)",
"x29": "Monthly Transport Pass (USD)",
"x30": "Taxi Start (Normal Tariff) (USD)",
"x31": "Taxi 1km (Normal Tariff) (USD)",
"x32": "Taxi 1 hour Waiting (USD)",
"x33": "Gasoline (1L) (USD)",
"x34": "Volkswagen Golf (New Car) (USD)",
"x35": "Toyota Corolla (New Car) (USD)",
"x36": "Utilities for 85m² Apartment (USD)",
"x37": "Mobile Tariff (1 min prepaid) (USD)",
"x38": "Internet (60+ Mbps unlimited) (USD)",
"x39": "Fitness Club Monthly Fee (USD)",
"x40": "Tennis Court Rent (1 hour weekend) (USD)",
"x41": "Cinema Ticket (USD)",
"x42": "Preschool Monthly (USD)",
"x43": "International Primary School Yearly (USD)",
"x44": "Jeans (Levis 501 or similar) (USD)",
"x45": "Summer Dress (Chain Store) (USD)",
"x46": "Nike Running Shoes (USD)",
"x47": "Men Leather Business Shoes (USD)",
"x48": "Apartment 1BR City Centre (USD)",
"x49": "Apartment 1BR Outside Centre (USD)",
"x50": "Apartment 3BR City Centre (USD)",
"x51": "Apartment 3BR Outside Centre (USD)",
"x52": "Price per m² Buy Apartment City Centre (USD)",
"x53": "Price per m² Buy Apartment Outside Centre (USD)",
"x54": "Average Monthly Net Salary (USD)",
"x55": "Mortgage Interest Rate (% yearly)"
}

food_cols = ["x9","x10","x11","x12","x13","x14","x15","x16","x17","x18","x19","x20","x21","x22"]
housing_cols = ["x48","x49","x50","x51","x52","x53"]
transport_cols = ["x28","x29","x30","x31","x33"]

# %%
#key indicators
df["Avg_Pct_Spent_Rent"] = df["x49"]/df["x54"] #average percent of monthly salary spent on rent
df["Months_to_Afford_1sqm"] = df["x54"] / df["x53"] #approximate number of months to afford a square meter of apartment
key_indicators = ["Avg_Pct_Spent_Rent","Months_to_Afford_1sqm"]
df.to_csv("cost-of-living_cleaned.csv")
